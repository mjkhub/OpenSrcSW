# %% [markdown]
# #lab1

# %%
minute = 456

hour =  456 / 60

minute = minute % 60

print(int(hour), minute) #hour에 대한 소수점 처리
# Out:
# 456분은 %d시간 %d분 입니다  7 36

# %% [markdown]
# lab 2

# %%
d = {"홍길동" : 3.4 , "임꺽정": 4.0, "김철수": 2.8, "이영희":3.9 }

k = d.keys()

k_list = list(k)
k_list.sort()

key = k_list[0]
value = d[key]
print(k_list)
print(key, value)
# Out:
# ['김철수', '이영희', '임꺽정', '홍길동']
# 김철수 2.8
